# %%
import pandas as pd
import os

# %%
dir_path = '/home/hshan/00_individual/SP2109/data/public_data/train_AT_TSALET_ALL/'

file_list = os.listdir(dir_path)
file_list = [s for s in file_list if "csv" in s]

# %%
file_list
# Out:
# ['AT_TSALET_ALL_201712.csv',
#  'AT_TSALET_ALL_201902.csv',
#  'AT_TSALET_ALL_201801.csv',
#  'AT_TSALET_ALL_201706.csv',
#  'AT_TSALET_ALL_201810.csv',
#  'AT_TSALET_ALL_201709.csv',
#  'AT_TSALET_ALL_201607.csv',
#  'AT_TSALET_ALL_201608.csv',
#  'AT_TSALET_ALL_201802.csv',
#  'AT_TSALET_ALL_201806.csv',
#  'AT_TSALET_ALL_201804.csv',
#  'AT_TSALET_ALL_201612.csv',
#  'AT_TSALET_ALL_201611.csv',
#  'AT_TSALET_ALL_201903.csv',
#  'AT_TSALET_ALL_201704.csv',
#  'AT_TSALET_ALL_201805.csv',
#  'AT_TSALET_ALL_201605.csv',
#  'AT_TSALET_ALL_201811.csv',
#  'AT_TSALET_ALL_201705.csv',
#  'AT_TSALET_ALL_201702.csv',
#  'AT_TSALET_ALL_201711.csv',
#  'AT_TSALET_ALL_201610.csv',
#  'AT_TSALET_ALL_201906.csv',
#  'AT_TSALET_ALL_201707.csv',
#  'AT_TSALET_ALL_201904.csv',
#  'AT_TSALET_ALL_201703.csv',
#  'AT_TSALET_ALL_201601.csv',
#  'AT_TSALET_ALL_201812.csv',
#  'AT_TSALET_ALL_201710.csv',
#  'AT_TSALET_ALL_201606.csv',
#  'AT_TSALET_ALL_201803.csv',
#  'AT_TSALET_ALL_201604.csv',
# ...

# %%
df = pd.DataFrame()
for file in file_list:

#     t1 = pd.read_csv(dir_path+file, error_bad_lines=False, engine='python')
    t1 = pd.read_csv(dir_path+file, engine='python', encoding='EUC-KR')
    df = df.append(t1)
    break
    
# df = df.sort_values('SALEDATE').iloc[2:]
# Out:
# --------------------------------------------------------------------------
# UnicodeDecodeError                       Traceback (most recent call last)
# <ipython-input-25-3f4e32a5c7ce> in <module>
#       3
#       4 #     t1 = pd.read_csv(dir_path+file, error_bad_lines=False, engine='python')
# ----> 5     t1 = pd.read_csv(dir_path+file, engine='python', encoding='EUC-KR')
#       6     df = df.append(t1)
#       7     break
#
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# df.to_pickle('/home/hshan/00_individual/SP2109/pp_data/public_train_data.pkl')

# %%
df.head()
# Out:
#         SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 567368  20160101   충주도매시장   중원청과     감귤     조생귤     kg     상자       .     상
# 567348  20160101   충주도매시장   중원청과     감귤     조생귤     kg     상자       .     상
# 567347  20160101   충주도매시장   중원청과     감귤     조생귤     kg     상자       .     상
# 567346  20160101   충주도매시장   중원청과     감귤     조생귤     kg     상자       .     상
# 567345  20160101   충주도매시장   중원청과     감귤     황금향     kg     상자       .     상
#
#          SAN_NM  DANQ   QTY     COST  TOT_QTY   TOT_AMT
# 567368  제주 서귀포시  10.0  58.0  11000.0    580.0  638000.0
# 567348  제주 남제주군   5.0  26.0   4000.0    130.0  104000.0
# 567347  제주 남제주군   5.0  14.0   3000.0     70.0   42000.0
# 567346  제주 남제주군   5.0   5.0   2000.0     25.0   10000.0
# 567345  제주 남제주군   3.0   8.0   9500.0     24.0   76000.0

# %%
import csv

# %%
dat1_list = []
dat2_list = []

with open(dir_path+'AT_TSALET_ALL_201902.csv', 'r') as raw:
    reader = csv.reader(raw)
    for lines in reader:
#         print(lines)
        dat1_list.append(lines)
        start = len(dat2_list)
        dat2_list[start:start] = lines

# %%
len(dat1_list)
# Out:
# 68317

# %%
a = pd.DataFrame(dat1_list)
a.rename(columns=a.iloc[0], inplace=True)
a.drop(a.index[0], inplace=True)

# %%
len(a)
# Out:
# 68316

# %%
a['SALEDATE'].unique()
# Out:
# array(['20190209', '20190208'], dtype=object)

# %%
dat2_list
# Out:
# ['SALEDATE',
#  'WHSAL_NM',
#  'CMP_NM',
#  'PUM_NM',
#  'KIND_NM',
#  'DAN_NM',
#  'POJ_NM',
#  'SIZE_NM',
#  'LV_NM',
#  'SAN_NM',
#  'DANQ',
#  'QTY',
#  'COST',
#  'TOT_QTY',
#  'TOT_AMT',
#  '20190209',
#  '대구북부도매',
#  '대양청과',
#  '호박',
#  '쥬키니호박',
#  'kg',
#  '상자',
#  '.',
#  '등외',
#  '경상북도 성주군',
#  '10.0',
#  '25',
#  '4500',
#  '250.0',
#  '112500',
#  '20190209',
#  '대구북부도매',
#  '대양청과',
#  '호박',
#  '쥬키니호박',
#  'kg',
#  '상자',
#  '.',
#  '보통',
#  '경상북도 성주군',
#  '10.0',
#  '27',
#  '4000',
#  '270.0',
#  '108000',
#  '20190209',
#  '대구북부도매',
#  '대양청과',
#  '호박',
#  '쥬키니호박',
#  'kg',
#  '상자',
#  '.',
#  '4등',
#  '경상북도 성주군',
#  '10.0',
#  '2',
#  '2000',
#  '20.0',
#  '4000',
#  '20190209',
#  '대구북부도매',
#  '대양청과',
#  '쪽파',
#  '깐쪽파',
#  'kg',
#  '상자',
#  '.',
#  '특',
#  '제주도 제주시',
#  '10.0',
#  '1',
#  '45000',
#  '10.0',
#  '45000',
#  '20190209',
#  '대구북부도매',
#  '대양청과',
#  '가지',
#  '가지(일반)',
#  'kg',
#  '상자',
#  '.',
#  '특',
#  '경상남도 밀양시',
#  '5.0',
#  '45',
#  '12000',
# ...

# %%
a
# Out:
#        SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 1      20190209   대구북부도매   대양청과     호박   쥬키니호박     kg     상자       .    등외
# 2      20190209   대구북부도매   대양청과     호박   쥬키니호박     kg     상자       .    보통
# 3      20190209   대구북부도매   대양청과     호박   쥬키니호박     kg     상자       .    4등
# 4      20190209   대구북부도매   대양청과     쪽파     깐쪽파     kg     상자       .     특
# 5      20190209   대구북부도매   대양청과     가지  가지(일반)     kg     상자       .     특
# ...         ...      ...    ...    ...     ...    ...    ...     ...   ...
# 68312  20190208   광주각화도매   광주청과     단감      부유     kg     상자       .     특
# 68313  20190208   광주각화도매   광주청과     단감      부유     kg     상자       .     특
# 68314  20190208   광주각화도매   광주청과     단감      부유     kg     상자       .     특
# 68315  20190208   광주각화도매   광주청과     단감      부유     kg     상자       .     특
# 68316  20190208   광주각화도매   광주청과     딸기      설향     kg     상자       .     특
#
#          SAN_NM  DANQ QTY   COST TOT_QTY TOT_AMT
# ...
